# %% [markdown]
# # 06 — Array Geometry and Beam Patterns
#
# This notebook introduces the ULA, steering vectors, and beam patterns.

# %% [markdown]
# ## Setup
#
# Import only beginner-local helpers and standard scientific Python packages.

# %%
from beginner._shared import RADAR_CONSTANTS
from beginner._shared.plotting import apply_notebook_style

apply_notebook_style()
cfg = RADAR_CONSTANTS
cfg

# %% [markdown]
# ## Guided exploration
#
# This section will visualize steering and beam gain versus angle.

# %% [markdown]
# ## Recap
#
# The learner should be able to explain main lobes, sidelobes, and grating lobes.
