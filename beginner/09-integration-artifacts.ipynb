# %% [markdown]
# # 09 — Integration and Portfolio Artifacts
#
# This notebook connects the full chain and produces the final beginner portfolio artifacts.

# %% [markdown]
# ## Setup
#
# Import the shared beginner helpers and standard scientific Python packages.

# %%
from beginner.helpers import RADAR_CONSTANTS
from beginner.helpers.plotting import apply_notebook_style

# Set the shared notebook styling once for consistent plots.
apply_notebook_style()

# Give the baseline radar settings a descriptive name for the lesson.
radar_spec = RADAR_CONSTANTS
radar_spec

# %% [markdown]
# ## Guided exploration
#
# This section will gather the final plots, captions, and takeaways.

# %% [markdown]
# ## Recap
#
# You should now be able to describe the full radar learning story from waveform to nulling.
