# %% [markdown]
# # 09 — Beam Steering and Adaptive Nulling
#
# This notebook shows steering toward the target and placing a null on the interferer.

# %% [markdown]
# ## Setup
#
# Import the shared beginner helpers and standard scientific Python packages.

# %%
from beginner.helpers import RADAR_CONSTANTS
from beginner.helpers.plotting import apply_notebook_style

# Set the shared notebook styling once for consistent plots.
apply_notebook_style()

# Give the baseline radar settings a descriptive name for the lesson.
radar_spec = RADAR_CONSTANTS
radar_spec

# %% [markdown]
# ## Guided exploration
#
# This section will build beam-steering weights and null-steering weights.

# %% [markdown]
# ## Recap
#
# You should now be able to explain how the null preserves the target while suppressing interference.
