# %% [markdown]
# # 08 — Beam Steering and Adaptive Nulling
#
# This notebook shows steering toward the target and placing a null on the interferer.

# %% [markdown]
# ## Setup
#
# Import only beginner-local helpers and standard scientific Python packages.

# %%
from beginner._shared import RADAR_CONSTANTS
from beginner._shared.plotting import apply_notebook_style

apply_notebook_style()
cfg = RADAR_CONSTANTS
cfg

# %% [markdown]
# ## Guided exploration
#
# This section will build beam-steering weights and null-steering weights.

# %% [markdown]
# ## Recap
#
# The learner should be able to explain how the null preserves the target while suppressing interference.
