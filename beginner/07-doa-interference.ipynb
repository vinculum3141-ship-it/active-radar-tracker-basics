# %% [markdown]
# # 07 — DOA and Interference
#
# This notebook compares Bartlett and Capon, then introduces a strong interferer.

# %% [markdown]
# ## Setup
#
# Import only beginner-local helpers and standard scientific Python packages.

# %%
from beginner._shared import RADAR_CONSTANTS
from beginner._shared.plotting import apply_notebook_style

apply_notebook_style()
cfg = RADAR_CONSTANTS
cfg

# %% [markdown]
# ## Guided exploration
#
# This section will compare DOA methods and show target masking by interference.

# %% [markdown]
# ## Recap
#
# The learner should be able to explain why Capon resolves tighter angles than Bartlett.
